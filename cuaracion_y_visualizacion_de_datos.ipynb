# %% [markdown]
# <a href="https://colab.research.google.com/github/romangasp/machine-learning/blob/main/cuaracion_y_visualizacion_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#manipulacion de datos y manejo de ellos
import pandas as pd
import numpy as np ##manejo de arreglos/vectores

#Visualizacion
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# %%
from google.colab import drive

# %%
#Base de datos cruda
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#raw_df = pd.read_csv("content/drive/MyDrive/penguins_raws.csv")
#procedemos a traer la base de datos cruda desde su url
url = "https://raw.githubusercontent.com/allisonhorst/palmerpenguins/master/inst/extdata/penguins.csv"
raw_df = pd.read_csv(url)

# %%
#view first 5 rows
raw_df.head(10)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
# 6  Adelie  Torgersen            38.9           17.8              181.0
# 7  Adelie  Torgersen            39.2           19.6              195.0
# 8  Adelie  Torgersen            34.1           18.1              193.0
# 9  Adelie  Torgersen            42.0           20.2              190.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007
# ...

# %%
#We see speed data from data set
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
#  7   year               344 non-null    int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 21.6+ KB

# %%
#We changes the type data object to categoric
raw_df = raw_df.astype({"species":"category","island":"category","sex":"category"})
#change only one
#raw_df["species"] = raw_df["species"].astype('object')

# %%
#raw_df.describe(include="all") para traer todo, all numericos y categoricos
#raw_df.describe(include="category")
raw_df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000
#
#               year
# count   344.000000
# mean   2008.029070
# std       0.818356
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %%
#we see the dimension of our data set
raw_df.shape
# Out:
# (344, 8)

# %%
#we see the type of data that contain each column
raw_df.dtypes
# Out:
# species              category
# island               category
# bill_length_mm        float64
# bill_depth_mm         float64
# flipper_length_mm     float64
# body_mass_g           float64
# sex                  category
# year                    int64
# dtype: object

# %%
#we see if there are null values
raw_df.isnull().any()
# Out:
# species              False
# island               False
# bill_length_mm        True
# bill_depth_mm         True
# flipper_length_mm     True
# body_mass_g           True
# sex                   True
# year                 False
# dtype: bool

# %%
raw_df.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %%
#How many null values i have by column
raw_df.isnull().sum().sum()
# Out:
# 19

# %%
#total cantity for each species
raw_df.value_counts(["species"])
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
#total cantity for each species e island
pd.DataFrame(raw_df.value_counts(["species","island"]))
# Out:
#                      count
# species   island
# Gentoo    Biscoe       124
# Chinstrap Dream         68
# Adelie    Dream         56
#           Torgersen     52
#           Biscoe        44

# %%
#total cantity for each species, island and sex
pd.DataFrame(raw_df.value_counts(["species","island","sex"]))
# Out:
#                             count
# species   island    sex
# Gentoo    Biscoe    male       61
#                     female     58
# Chinstrap Dream     female     34
#                     male       34
# Adelie    Dream     male       28
#                     female     27
#           Torgersen female     24
#                     male       23
#           Biscoe    female     22
#                     male       22

# %%
#raw_df['flipper_length_mm'].max()
raw_df['flipper_length_mm'].min()
#raw_df['flipper_length_mm'].mean()
# Out:
# 172.0

# %%
raw_df.isnull().any(axis=1)
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Length: 344, dtype: bool

# %%
#we get those rows that have null values
null_condition = raw_df.isnull().any(axis=1) #with axis we indicate which axis should be take
raw_df[null_condition]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 8    Adelie  Torgersen            34.1           18.1              193.0
# 9    Adelie  Torgersen            42.0           20.2              190.0
# 10   Adelie  Torgersen            37.8           17.1              186.0
# 11   Adelie  Torgersen            37.8           17.3              180.0
# 47   Adelie      Dream            37.5           18.9              179.0
# 178  Gentoo     Biscoe            44.5           14.3              216.0
# 218  Gentoo     Biscoe            46.2           14.4              214.0
# 256  Gentoo     Biscoe            47.3           13.8              216.0
# 268  Gentoo     Biscoe            44.5           15.7              217.0
# 271  Gentoo     Biscoe             NaN            NaN                NaN
#
#      body_mass_g  sex  year
# 3            NaN  NaN  2007
# 8         3475.0  NaN  2007
# ...

# %%
#we make the long
print(len(raw_df[null_condition]))
# Out:
# 11

# %%
a = raw_df

# %%
a = a.dropna() #to delete the null values
a
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 4       Adelie  Torgersen            36.7           19.3              193.0
# 5       Adelie  Torgersen            39.3           20.6              190.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %%
a.dropna(inplace = True)
# Out:
# <ipython-input-67-eecc39fa79f4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.dropna(inplace = True)

# %%
a
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 4       Adelie  Torgersen            36.7           19.3              193.0
# 5       Adelie  Torgersen            39.3           20.6              190.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %%
#we make three differents copies from raw dataset
df_without_null = raw_df.copy()
df_fill_nan = raw_df.copy()
df = raw_df.copy()

# %%
#we delete all the rows that have null values
df_without_null.dropna(inplace = True)

# %%
#we verify if there aren't null values
df_without_null.isnull().any().sum().sum()
# Out:
# 0

# %%
#we fill the null values with your "moda" to the categoric and with the mean to the numerics
#df_fill_nan["sex"].value_counts()
df_fill_nan["sex"].value_counts(dropna = False)
# Out:
# sex
# male      168
# female    165
# NaN        11
# Name: count, dtype: int64

# %%
df_fill_nan["sex"].mode()[0]
# Out:
# 'male'

# %%
pd.DataFrame(df_fill_nan["sex"])
# Out:
#         sex
# 0      male
# 1    female
# 2    female
# 3       NaN
# 4    female
# ..      ...
# 339    male
# 340  female
# 341    male
# 342    male
# 343  female
#
# [344 rows x 1 columns]

# %%
moda = df_fill_nan["sex"].mode()[0]
moda
# Out:
# 'male'

# %%
pd.DataFrame(df_fill_nan["sex"])
# Out:
#         sex
# 0      male
# 1    female
# 2    female
# 3       NaN
# 4    female
# ..      ...
# 339    male
# 340  female
# 341    male
# 342    male
# 343  female
#
# [344 rows x 1 columns]

# %%
df_fill_nan["sex"].fillna(moda,inplace = True)

# %%
pd.DataFrame(df_fill_nan["sex"])
# Out:
#         sex
# 0      male
# 1    female
# 2    female
# 3      male
# 4    female
# ..      ...
# 339    male
# 340  female
# 341    male
# 342    male
# 343  female
#
# [344 rows x 1 columns]

# %%
pd.DataFrame(df_fill_nan["sex"])
# Out:
#         sex
# 0      male
# 1    female
# 2    female
# 3      male
# 4    female
# ..      ...
# 339    male
# 340  female
# 341    male
# 342    male
# 343  female
#
# [344 rows x 1 columns]

# %%
df_fill_nan
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %%
#I delete the row with index 3 and 273
df.drop([3,271], axis=0,inplace=True)

# %%
df[df.isnull().any(axis=1)]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 8    Adelie  Torgersen            34.1           18.1              193.0
# 9    Adelie  Torgersen            42.0           20.2              190.0
# 10   Adelie  Torgersen            37.8           17.1              186.0
# 11   Adelie  Torgersen            37.8           17.3              180.0
# 47   Adelie      Dream            37.5           18.9              179.0
# 178  Gentoo     Biscoe            44.5           14.3              216.0
# 218  Gentoo     Biscoe            46.2           14.4              214.0
# 256  Gentoo     Biscoe            47.3           13.8              216.0
# 268  Gentoo     Biscoe            44.5           15.7              217.0
#
#      body_mass_g  sex  year
# 8         3475.0  NaN  2007
# 9         4250.0  NaN  2007
# 10        3300.0  NaN  2007
# 11        3700.0  NaN  2007
# 47        2975.0  NaN  2007
# 178       4100.0  NaN  2007
# 218       4650.0  NaN  2008
# ...

# %%
# I replace the slack data of the column sex by the 'moda'
df['sex'].fillna(df['sex'].mode()[0], inplace=True)

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex, year]
# Index: []
